# %% [markdown]
# **Price of The Car**
#
# ---

# %%
link = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'

import pandas as pd
df = pd.read_csv(link)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
df['stroke'].isnull().sum()
# Out:
# 4

# %%
df['horsepower-binned'].isnull().sum()
# Out:
# 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
import numpy as np

# %%
df['horsepower-binned'].value_counts()
# Out:
# horsepower-binned
# Low       115
# Medium     62
# High       23
# Name: count, dtype: int64

# %%
df['horsepower-binned'].value_counts().idxmax()
# Out:
# 'Low'

# %%
#replace the missing value for num-of-doors

df['horsepower-binned'].replace(np.nan, df['horsepower-binned'].value_counts().idxmax(), inplace=True)

df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
df['stroke'].replace(np.nan, df['stroke'].mean(), inplace=True)

df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
df_numeric = df.select_dtypes(include=['number'])

df_numeric.corr()  #to see the correlation among the numeric features
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#          symboling  normalized-losses    make aspiration num-of-doors  \
# count   201.000000          201.00000     201        201          201
# unique         NaN                NaN      22          2            2
# top            NaN                NaN  toyota        std         four
# freq           NaN                NaN      32        165          115
# mean      0.840796          122.00000     NaN        NaN          NaN
# std       1.254802           31.99625     NaN        NaN          NaN
# min      -2.000000           65.00000     NaN        NaN          NaN
# 25%       0.000000          101.00000     NaN        NaN          NaN
# 50%       1.000000          122.00000     NaN        NaN          NaN
# 75%       2.000000          137.00000     NaN        NaN          NaN
# max       3.000000          256.00000     NaN        NaN          NaN
#
#        body-style drive-wheels engine-location  wheel-base      length  ...  \
# ...

# %%
ndf = df[['symboling', 'normalized-losses','wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'city-L/100km', 'diesel', 'gas', 'price']]


ndf.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df_numeric = df.select_dtypes(include=['number'])

df_numeric.corr()  #to see the correlation among the numeric features
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.regplot(x="normalized-losses", y="price", data=df)
# Out:
# <Axes: xlabel='normalized-losses', ylabel='price'>

# %%
sns.regplot(x="symboling", y="price", data=df)
# Out:
# <Axes: xlabel='symboling', ylabel='price'>

# %%
sns.regplot(x="wheel-base", y="price", data=df)
# Out:
# <Axes: xlabel='wheel-base', ylabel='price'>

# %%
sns.regplot(x="length", y="price", data=df)
# Out:
# <Axes: xlabel='length', ylabel='price'>

# %%
sns.regplot(x="width", y="price", data=df)
# Out:
# <Axes: xlabel='width', ylabel='price'>

# %%
sns.regplot(x="height", y="price", data=df)
# Out:
# <Axes: xlabel='height', ylabel='price'>

# %%
sns.regplot(x="curb-weight", y="price", data=df)
# Out:
# <Axes: xlabel='curb-weight', ylabel='price'>

# %%
sns.regplot(x="engine-size", y="price", data=df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(x="bore", y="price", data=df)
# Out:
# <Axes: xlabel='bore', ylabel='price'>

# %%
sns.regplot(x="stroke", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
sns.regplot(x="compression-ratio", y="price", data=df)
# Out:
# <Axes: xlabel='compression-ratio', ylabel='price'>

# %%
sns.regplot(x="horsepower", y="price", data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
sns.regplot(x="peak-rpm", y="price", data=df)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
sns.regplot(x="city-mpg", y="price", data=df)
# Out:
# <Axes: xlabel='city-mpg', ylabel='price'>

# %%
sns.regplot(x="highway-mpg", y="price", data=df)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
sns.regplot(x="city-L/100km", y="price", data=df)
# Out:
# <Axes: xlabel='city-L/100km', ylabel='price'>

# %%
sns.regplot(x="diesel", y="price", data=df)
# Out:
# <Axes: xlabel='diesel', ylabel='price'>

# %%
sns.regplot(x="gas", y="price", data=df)
# Out:
# <Axes: xlabel='gas', ylabel='price'>

# %%
import numpy as np

msk = np.random.rand(len(df)) <= 0.8
train = df[msk]
test = df[~msk] #take the rest of the data #randomly choosing

#it mean 80% will be choose randomly

# %%
df_numeric = df.select_dtypes(include=['number'])

df_numeric.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
from sklearn import linear_model #call all the linear model - then call algorithm (linear regression)

regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['width']])
train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)
# Out:
# LinearRegression()

# %%
x = 2.4

y = regr.intercept_ + regr.coef_ *x

y
# Out:
# array([[311571.50839771]])

# %%
from sklearn.metrics import r2_score

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['width']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['width']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 56.6
# The MSE is: 2602231625.8
# The MAE is: 323566.98

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['curb-weight']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['curb-weight']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 67.59
# The MSE is: 1942880007.39
# The MAE is: 284626.3

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['engine-size']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['engine-size']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 77.11
# The MSE is: 1372653961.6
# The MAE is: 264700.1

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['length']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['length']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 45.61
# The MSE is: 3260678956.63
# The MAE is: 390283.57

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['horsepower']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['horsepower']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 64.5
# The MSE is: 2128320955.15
# The MAE is: 327530.83

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['city-mpg']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['city-mpg']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 47.81
# The MSE is: 3129213132.14
# The MAE is: 403817.21

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['city-L/100km']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['city-L/100km']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 62.92
# The MSE is: 2222823855.37
# The MAE is: 336059.73

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['compression-ratio']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['compression-ratio']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 0.03
# The MSE is: 5993556487.5
# The MAE is: 566288.65

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['stroke']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['stroke']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 0.72
# The MSE is: 5952310092.29
# The MAE is: 569715.33

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['wheel-base']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['wheel-base']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 32.77
# The MSE is: 4031011199.0
# The MAE is: 416098.1

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['symboling']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['symboling']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 0.02
# The MSE is: 5994369175.26
# The MAE is: 567391.81

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['highway-mpg']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['highway-mpg']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 50.18
# The MSE is: 2987164520.74
# The MAE is: 392752.26

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['diesel']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['diesel']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 0.37
# The MSE is: 5973533592.5
# The MAE is: 564679.84

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['gas']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['gas']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 0.37
# The MSE is: 5973533592.5
# The MAE is: 564679.84

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['height']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['height']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 1.41
# The MSE is: 5911162071.73
# The MAE is: 564129.8

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['bore']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['bore']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 28.2
# The MSE is: 4304923786.99
# The MAE is: 447733.61

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['normalized-losses']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['normalized-losses']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 4.55
# The MSE is: 5722692743.94
# The MAE is: 527614.07

# %%
regr = linear_model.LinearRegression()

#Mention and label the x and y

train_x = np.asanyarray(train[['peak-rpm']])

train_y = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr.fit (train_x, train_y)

#prediction

test_x = np.asanyarray(train[['peak-rpm']])
test_y = np.asanyarray(train[['price']]) #actual test

test_y_ = regr.predict(test_x)

#Evaluation

print('The R2 is:', round(((r2_score(test_y, test_y_))*100), 2))

print('The MSE is:', round((((np.mean((test_y_ - test_y)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y_ - test_y))))*100), 2))
# Out:
# The R2 is: 0.9
# The MSE is: 5941768710.74
# The MAE is: 567381.74

# %%
#multiple linear regresssion

# %%
regr1 = linear_model.LinearRegression()

#Mention and label the x and y

train_x1 = np.asanyarray(train[['highway-mpg', 'city-L/100km', 'city-mpg']])

train_y1 = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr1.fit (train_x1, train_y1)

#prediction

test_x1 = np.asanyarray(train[['highway-mpg', 'city-L/100km', 'city-mpg']])
test_y1 = np.asanyarray(train[['price']]) #actual test

test_y1_ = regr1.predict(test_x1)

#Evaluation

print('The R2 is:', round(((r2_score(test_y1, test_y1_))*100), 2))

print('The MSE is:', round((((np.mean((test_y1_ - test_y1)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y1_ - test_y1))))*100), 2))
# Out:
# The R2 is: 69.52
# The MSE is: 1827564223.68
# The MAE is: 287886.97

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
regr1 = linear_model.LinearRegression()

#Mention and label the x and y

train_x1 = np.asanyarray(train[['width', 'length', 'city-mpg', 'highway-mpg']])

train_y1 = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr1.fit (train_x1, train_y1)

#prediction

test_x1 = np.asanyarray(train[['width', 'length', 'city-mpg', 'highway-mpg']])
test_y1 = np.asanyarray(train[['price']]) #actual test

test_y1_ = regr1.predict(test_x1)

#Evaluation

print('The R2 is:', round(((r2_score(test_y1, test_y1_))*100), 2))

print('The MSE is:', round((((np.mean((test_y1_ - test_y1)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y1_ - test_y1))))*100), 2))
# Out:
# The R2 is: 64.14
# The MSE is: 2150123378.4
# The MAE is: 312574.4

# %%
regr1 = linear_model.LinearRegression()

#Mention and label the x and y

train_x1 = np.asanyarray(train[['horsepower', 'engine-size', 'city-L/100km','curb-weight']])

train_y1 = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr1.fit (train_x1, train_y1)

#prediction

test_x1 = np.asanyarray(train[['horsepower', 'engine-size', 'city-L/100km','curb-weight']])
test_y1 = np.asanyarray(train[['price']]) #actual test

test_y1_ = regr1.predict(test_x1)

#Evaluation

print('The R2 is:', round(((r2_score(test_y1, test_y1_))*100), 2))

print('The MSE is:', round((((np.mean((test_y1_ - test_y1)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y1_ - test_y1))))*100), 2))
# Out:
# The R2 is: 81.97
# The MSE is: 1080721585.42
# The MAE is: 236883.32

# %%
regr1 = linear_model.LinearRegression()

#Mention and label the x and y

train_x1 = np.asanyarray(train[['horsepower', 'engine-size', 'city-L/100km','curb-weight', 'width', 'length', 'city-mpg', 'highway-mpg']])

train_y1 = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr1.fit (train_x1, train_y1)

#prediction

test_x1 = np.asanyarray(train[['horsepower', 'engine-size', 'city-L/100km','curb-weight', 'width', 'length', 'city-mpg', 'highway-mpg']])
test_y1 = np.asanyarray(train[['price']]) #actual test

test_y1_ = regr1.predict(test_x1)

#Evaluation

print('The R2 is:', round(((r2_score(test_y1, test_y1_))*100), 2))

print('The MSE is:', round((((np.mean((test_y1_ - test_y1)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y1_ - test_y1))))*100), 2))
# Out:
# The R2 is: 84.93
# The MSE is: 903565297.33
# The MAE is: 209001.77

# %%
regr1 = linear_model.LinearRegression()

#Mention and label the x and y

train_x1 = np.asanyarray(train[['horsepower', 'engine-size', 'city-L/100km','curb-weight', 'width', 'length', 'city-mpg', 'highway-mpg', 'diesel', 'gas']])

train_y1 = np.asanyarray(train[['price']])
#need to use array - convert from panda

#training
regr1.fit (train_x1, train_y1)

#prediction

test_x1 = np.asanyarray(train[['horsepower', 'engine-size', 'city-L/100km','curb-weight', 'width', 'length', 'city-mpg', 'highway-mpg', 'diesel', 'gas']])
test_y1 = np.asanyarray(train[['price']]) #actual test

test_y1_ = regr1.predict(test_x1)

#Evaluation

print('The R2 is:', round(((r2_score(test_y1, test_y1_))*100), 2))

print('The MSE is:', round((((np.mean((test_y1_ - test_y1)**2)))*100), 2))

print('The MAE is:', round ((((np.mean(np.absolute(test_y1_ - test_y1))))*100), 2))
# Out:
# The R2 is: 85.69
# The MSE is: 857836030.48
# The MAE is: 211465.08

# %%
#control the size of visualization

plt.figure(figsize=(18,12)) #normally not more than 18, height is up to you

sns.heatmap(df_numeric.corr(), annot=True, cmap='RdBu')
# Out:
# <Axes: >

# %%
import pandas as pd

def calculate_and_sort_correlations(data, target_feature):
    """
    Calculate the correlation of the target_feature to all other features
    and sort them in ascending order.

    Parameters:
    data (pd.DataFrame): The dataset containing the features.
    target_feature (str): The feature to calculate correlations against.

    Returns:
    pd.Series: Correlations of target_feature with other features, sorted in ascending order.
    """
    # Calculate the correlation matrix
    correlation_matrix = data.corr(numeric_only=True)

    # Extract the correlations for the target feature
    correlations = correlation_matrix[target_feature]

    # Drop the target feature itself
    correlations = correlations.drop(target_feature)

    # Sort the correlations in ascending order
    sorted_correlations = correlations.sort_values(ascending=True)

    return sorted_correlations

# %%
calculate_and_sort_correlations(df, 'price')
# Out:
# highway-mpg         -0.704692
# city-mpg            -0.686571
# gas                 -0.110326
# peak-rpm            -0.101616
# symboling           -0.082391
# compression-ratio    0.071107
# stroke               0.082267
# diesel               0.110326
# normalized-losses    0.133999
# height               0.135486
# bore                 0.543155
# wheel-base           0.584642
# length               0.690628
# width                0.751265
# city-L/100km         0.789898
# horsepower           0.809575
# curb-weight          0.834415
# engine-size          0.872335
# Name: price, dtype: float64
